# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM 3
#
# This notebook demonstrates how to use SAM 3 for interactive video segmentation and dense tracking. It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# # <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam3/blob/main/notebooks/sam3_video_predictor_example.ipynb">
# #   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# # </a>

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib scikit-learn
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam3.git'

# %%
# !nvidia-smi
# Out:
# Sun Mar 29 17:00:27 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.07             Driver Version: 581.80         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 Ti     On  |   00000000:01:00.0  On |                  N/A |
# |  0%   42C    P2             37W /  285W |    8022MiB /  12282MiB |      9%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A              38      G   /Xwayland                             N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Set-up
#
# In this example, we allow running inference either on a single GPU or multiple GPUs.

# %%
import os
import sys
import subprocess
from pathlib import Path

import torch


def _find_local_sam3_repo(start_dir: Path) -> Path | None:
    """Find local SAM3 repo root that contains pyproject.toml and package source."""
    for p in [start_dir, *start_dir.parents]:
        nested_repo = p / "sam3"
        if (nested_repo / "pyproject.toml").exists() and (nested_repo / "sam3" / "__init__.py").exists():
            return nested_repo
        if (p / "pyproject.toml").exists() and (p / "sam3" / "__init__.py").exists():
            return p
    return None


sam3_repo = _find_local_sam3_repo(Path.cwd().resolve())
if sam3_repo is not None and str(sam3_repo) not in sys.path:
    sys.path.insert(0, str(sam3_repo))

try:
    import sam3
except ModuleNotFoundError:
    if sam3_repo is None:
        raise ModuleNotFoundError(
            "Could not find a local SAM3 repo. Install SAM3 first, e.g. `pip install -e /path/to/sam3`."
        )
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(sam3_repo)])
    import sam3

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")

# use all available GPUs on the machine
gpus_to_use = range(torch.cuda.device_count())
# # use only a single GPU
# gpus_to_use = [torch.cuda.current_device()]
# Out:
# /mnt/e/side_projects/efficientsam3/sam3/sam3/model_builder.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /home/simon7108528_msi_linux/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
from sam3.model_builder import build_sam3_video_predictor

predictor = build_sam3_video_predictor(gpus_to_use=gpus_to_use)
# Out:
# INFO 2026-03-29 17:00:30,261 478492 sam3_video_predictor.py: 109: using the following GPU IDs: [0]
# INFO 2026-03-29 17:00:30,357 478492 sam3_video_predictor.py: 125:
#
#
# 	*** START loading model on all ranks ***
#
#
# INFO 2026-03-29 17:00:30,358 478492 sam3_video_predictor.py: 127: loading model on rank=0 with world_size=1 -- this could take a while ...
# INFO 2026-03-29 17:00:35,190 478492 sam3_video_base.py: 348: setting max_num_objects=10000 and num_obj_for_compile=16
# INFO 2026-03-29 17:00:40,434 478492 sam3_video_predictor.py: 129: loading model on rank=0 with world_size=1 -- DONE locally
# INFO 2026-03-29 17:00:40,435 478492 sam3_video_predictor.py: 140:
#
#
# 	*** DONE loading model on all ranks ***

# %% [markdown]
# #### Inference and visualization utils

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

# font size for axes titles
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    # we will just propagate from frame 0 to the end of the video
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
video_path = f"{sam3_root}/assets/videos/0001"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (image folder) [rank=0]: 100%|██████████| 270/270 [00:04<00:00, 54.50it/s]
# INFO 2026-03-29 17:00:47,418 478492 sam3_base_predictor.py: 130: started new session 2089e16c-8de7-45b2-b763-aaab5bf89c7a

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = predictor.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)

# %%
prompt_text_str = "person"
frame_idx = 0  # add a text prompt on frame 0
response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
# propagate_in_video:   0%|          | 0/270 [00:00<?, ?it/s]
# INFO 2026-03-29 17:01:48,484 478492 sam3_base_predictor.py: 286: propagation ended in session 2089e16c-8de7-45b2-b763-aaab5bf89c7a
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # now we propagate the outputs from frame 0 to the end of the video and collect all outputs
# ----> 2 outputs_per_frame = propagate_in_video(predictor, session_id)
#       4 # finally, we reformat the outputs for visualization and plot the outputs every 60 frames
#       5 outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)
#
# Cell In[7], line 22, in propagate_in_video(predictor, session_id)
#      19 def propagate_in_video(predictor, session_id):
#      20     # we will just propagate from frame 0 to the end of the video
#      21     outputs_per_frame = {}
# ---> 22     for response in predictor.handle_stream_request(
#      23         request=dict(
#      24             type="propagate_in_video",
#      25             session_id=session_id,
#      26         )
#      27     ):
#      28         outputs_per_frame[response["frame_index"]] = response["outputs"]
#      30     return outputs_per_frame
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/torch/utils/_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      58         else:
#      59             # Pass the last request to the generator and get its response
#      60             with ctx_factory():
# ---> 61                 response = gen.send(request)
#      63 # We let the exceptions raised above by the generator's `.throw` or
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#      65 except StopIteration as e:
#      66     # The generator informed us that it is done: take whatever its
#      67     # returned value (if any) was and indicate that we're done too
#      68     # by returning it (see docs for python's return-statement).
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_predictor.py:178, in Sam3VideoPredictorMultiGPU.handle_stream_request(self, request)
#     175     for rank in range(1, self.world_size):
#     176         self.command_queues[rank].put((request, True))
# --> 178 yield from super().handle_stream_request(request)
#     180 if self.world_size > 1:
#     181     torch.distributed.barrier()
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/torch/utils/_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      58         else:
#      59             # Pass the last request to the generator and get its response
#      60             with ctx_factory():
# ---> 61                 response = gen.send(request)
#      63 # We let the exceptions raised above by the generator's `.throw` or
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#      65 except StopIteration as e:
#      66     # The generator informed us that it is done: take whatever its
#      67     # returned value (if any) was and indicate that we're done too
#      68     # by returning it (see docs for python's return-statement).
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_base_predictor.py:90, in Sam3BasePredictor.handle_stream_request(self, request)
#      88 request_type = request["type"]
#      89 if request_type == "propagate_in_video":
# ---> 90     yield from self.propagate_in_video(
#      91         session_id=request["session_id"],
#      92         propagation_direction=request.get("propagation_direction", "both"),
#      93         start_frame_idx=request.get("start_frame_index", None),
#      94         max_frame_num_to_track=request.get("max_frame_num_to_track", None),
#      95         output_prob_thresh=request.get(
#      96             "output_prob_thresh",
#      97             getattr(self, "default_output_prob_thresh", 0.5),
#      98         ),
#      99     )
#     100 else:
#     101     raise RuntimeError(f"invalid request type: {request_type}")
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_base_predictor.py:273, in Sam3BasePredictor.propagate_in_video(self, session_id, propagation_direction, start_frame_idx, max_frame_num_to_track, output_prob_thresh, **kwargs)
#     271 # Forward propagation
#     272 if propagation_direction in ["both", "forward"]:
# --> 273     for frame_idx, outputs in self.model.propagate_in_video(
#     274         **propagate_kwargs,
#     275         reverse=False,
#     276     ):
#     277         yield {"frame_index": frame_idx, "outputs": outputs}
#     278 # Backward propagation
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/torch/utils/_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      58         else:
#      59             # Pass the last request to the generator and get its response
#      60             with ctx_factory():
# ---> 61                 response = gen.send(request)
#      63 # We let the exceptions raised above by the generator's `.throw` or
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#      65 except StopIteration as e:
#      66     # The generator informed us that it is done: take whatever its
#      67     # returned value (if any) was and indicate that we're done too
#      68     # by returning it (see docs for python's return-statement).
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_inference.py:1017, in Sam3VideoInferenceWithInstanceInteractivity.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse)
#    1015 if propagation_type == "propagation_full":
#    1016     logger.debug(f"Running full VG propagation (reverse={reverse}).")
# -> 1017     yield from super().propagate_in_video(
#    1018         inference_state,
#    1019         start_frame_idx=start_frame_idx,
#    1020         max_frame_num_to_track=max_frame_num_to_track,
#    1021         reverse=reverse,
#    1022     )
#    1023     return
#    1025 # step 3: run Tracker partial propagation or direct fetch existing predictions
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/torch/utils/_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      58         else:
#      59             # Pass the last request to the generator and get its response
#      60             with ctx_factory():
# ---> 61                 response = gen.send(request)
#      63 # We let the exceptions raised above by the generator's `.throw` or
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#      65 except StopIteration as e:
#      66     # The generator informed us that it is done: take whatever its
#      67     # returned value (if any) was and indicate that we're done too
#      68     # by returning it (see docs for python's return-statement).
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_inference.py:293, in Sam3VideoInference.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse)
#     289 unconfirmed_obj_ids_per_frame = {}  # frame_idx -> hidden_obj_ids
#     290 for frame_idx in tqdm(
#     291     processing_order, desc="propagate_in_video", disable=self.rank > 0
#     292 ):
# --> 293     out = self._run_single_frame_inference(inference_state, frame_idx, reverse)
#     295     if self.hotstart_delay > 0:
#     296         # accumulate the outputs for the first `hotstart_delay` frames
#     297         hotstart_buffer.append([frame_idx, out])
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_inference.py:378, in Sam3VideoInference._run_single_frame_inference(self, inference_state, frame_idx, reverse)
#     367 has_geometric_prompt = (
#     368     inference_state["per_frame_geometric_prompt"][frame_idx] is not None
#     369 )
#     370 # run inference for the current frame
#     371 (
#     372     obj_id_to_mask,
#     373     obj_id_to_score,
#     374     tracker_states_local_new,
#     375     tracker_metadata_new,
#     376     frame_stats,
#     377     _,
# --> 378 ) = self._det_track_one_frame(
#     379     frame_idx=frame_idx,
#     380     num_frames=inference_state["num_frames"],
#     381     reverse=reverse,
#     382     input_batch=input_batch,
#     383     geometric_prompt=(
#     384         inference_state["constants"]["empty_geometric_prompt"]
#     385         if not has_geometric_prompt
#     386         else inference_state["per_frame_geometric_prompt"][frame_idx]
#     387     ),
#     388     tracker_states_local=tracker_states_local,
#     389     tracker_metadata_prev=inference_state["tracker_metadata"],
#     390     feature_cache=inference_state["feature_cache"],
#     391     orig_vid_height=inference_state["orig_height"],
#     392     orig_vid_width=inference_state["orig_width"],
#     393     is_image_only=inference_state["is_image_only"],
#     394     allow_new_detections=has_text_prompt or has_geometric_prompt,
#     395 )
#     396 # update inference state
#     397 inference_state["tracker_inference_states"] = tracker_states_local_new
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_base.py:407, in Sam3VideoBase._det_track_one_frame(self, frame_idx, num_frames, reverse, input_batch, geometric_prompt, tracker_states_local, tracker_metadata_prev, feature_cache, orig_vid_height, orig_vid_width, is_image_only, allow_new_detections)
#     390 """
#     391 This function handles one-step inference for the DenseTracking model in an SPMD manner.
#     392 At a high-level, all GPUs execute the same function calls as if it's done on a single GPU,
#    (...)
#     399   it contains both global and local masklet information
#     400 """
#     402 # Step 1: run backbone and detector in a distributed manner -- this is done via Sam3ImageOnVideoMultiGPU,
#     403 # a MultiGPU model (assigned to `self.detector`) that shards frames in a round-robin manner.
#     404 # It returns a "det_out" dict for `frame_idx` and fills SAM2 backbone features for `frame_idx`
#     405 # into `feature_cache`. Despite its distributed inference under the hood, the results would be
#     406 # the same as if it is running backbone and detector for every frame on a single GPU.
# --> 407 det_out = self.run_backbone_and_detection(
#     408     frame_idx=frame_idx,
#     409     num_frames=num_frames,
#     410     reverse=reverse,
#     411     input_batch=input_batch,
#     412     geometric_prompt=geometric_prompt,
#     413     feature_cache=feature_cache,
#     414     allow_new_detections=allow_new_detections,
#     415 )
#     417 # Step 2: each GPU propagates its local SAM2 states to get the SAM2 prediction masks.
#     418 # the returned `tracker_low_res_masks_global` contains the concatenated masklet predictions
#     419 # gathered from all GPUs (as if they are propagated on a single GPU). Note that this step only
#     420 # runs the SAM2 propagation step, but doesn't encode new memory for the predicted masks;
#     421 # we defer memory encoding to `run_tracker_update_execution_phase` after resolving all heuristics.
#     422 if tracker_metadata_prev == {}:
#     423     # initialize masklet metadata if it's uninitialized (empty dict)
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_video_base.py:568, in Sam3VideoBase.run_backbone_and_detection(self, frame_idx, num_frames, input_batch, geometric_prompt, feature_cache, reverse, allow_new_detections)
#     565 max_frame_num_to_track = tracking_bounds.get("max_frame_num_to_track")
#     566 start_frame_idx = tracking_bounds.get("propagate_in_video_start_frame_idx")
# --> 568 sam3_image_out, _ = self.detector.forward_video_grounding_multigpu(
#     569     backbone_out={
#     570         "img_batch_all_stages": input_batch.img_batch,
#     571         **text_outputs,
#     572     },
#     573     find_inputs=input_batch.find_inputs,
#     574     geometric_prompt=geometric_prompt,
#     575     frame_idx=frame_idx,
#     576     num_frames=num_frames,
#     577     multigpu_buffer=feature_cache["multigpu_buffer"],
#     578     track_in_reverse=reverse,
#     579     # also get the SAM2 backbone features
#     580     return_tracker_backbone_feats=True,
#     581     # run NMS as a part of distributed computation
#     582     run_nms=self.det_nms_thresh > 0.0,
#     583     nms_prob_thresh=self.score_threshold_detection,
#     584     nms_iou_thresh=self.det_nms_thresh,
#     585     # pass max_frame_num_to_track to respect tracking limits
#     586     max_frame_num_to_track=max_frame_num_to_track,
#     587     propagate_in_video_start_frame_idx=start_frame_idx,
#     588 )
#     589 # note: detections in `sam3_image_out` has already gone through NMS
#     590 pred_probs = sam3_image_out["pred_logits"].squeeze(-1).sigmoid()
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_image.py:802, in Sam3ImageOnVideoMultiGPU.forward_video_grounding_multigpu(self, backbone_out, find_inputs, geometric_prompt, frame_idx, num_frames, multigpu_buffer, track_in_reverse, return_sam2_backbone_feats, run_nms, nms_prob_thresh, nms_iou_thresh, **kwargs)
#     800 if frame_idx_next_b is not None and frame_idx_next_b not in multigpu_buffer:
#     801     with torch.profiler.record_function("build_multigpu_buffer_next_chunk2"):
# --> 802         self._build_multigpu_buffer_next_chunk(
#     803             backbone_out=backbone_out,
#     804             find_inputs=find_inputs,
#     805             geometric_prompt=geometric_prompt,
#     806             frame_idx_begin=frame_idx_next_b,
#     807             frame_idx_end=frame_idx_next_e,
#     808             num_frames=num_frames,
#     809             multigpu_buffer=multigpu_buffer,
#     810             run_nms=run_nms,
#     811             nms_prob_thresh=nms_prob_thresh,
#     812             nms_iou_thresh=nms_iou_thresh,
#     813         )
#     815 return out, backbone_out
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_image.py:835, in Sam3ImageOnVideoMultiGPU._build_multigpu_buffer_next_chunk(self, backbone_out, find_inputs, geometric_prompt, frame_idx_begin, frame_idx_end, num_frames, multigpu_buffer, run_nms, nms_prob_thresh, nms_iou_thresh)
#     833 # `forward_grounding` (from base class `Sam3ImageOnVideo`) runs the detector on a single frame
#     834 with torch.profiler.record_function("forward_grounding"):
# --> 835     out_local = self.forward_grounding(
#     836         backbone_out=backbone_out,
#     837         find_input=find_inputs[frame_idx_local_gpu],
#     838         find_target=None,
#     839         geometric_prompt=geometric_prompt,
#     840     )
#     841 if run_nms:
#     842     with torch.profiler.record_function("nms_masks"):
#     843         # run NMS as a post-processing step on top of the detection outputs
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_image.py:454, in Sam3Image.forward_grounding(self, backbone_out, find_input, find_target, geometric_prompt, **kwargs)
#     452 # Run the encoder
#     453 with torch.profiler.record_function("SAM3Image._run_encoder"):
# --> 454     backbone_out, encoder_out, _ = self._run_encoder(
#     455         backbone_out, find_input, prompt, prompt_mask
#     456     )
#     457 out = {
#     458     "encoder_hidden_states": encoder_out["encoder_hidden_states"],
#     459     "prev_encoder_out": {
#    (...)
#     462     },
#     463 }
#     465 # Run the decoder
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/sam3_image.py:226, in Sam3Image._run_encoder(self, backbone_out, find_input, prompt, prompt_mask, encoder_extra_kwargs)
#     224 prompt_pos_embed = torch.zeros_like(prompt)
#     225 # make a copy of the image feature lists since the encoder may modify these lists in-place
# --> 226 memory = self.transformer.encoder(
#     227     src=img_feats.copy(),
#     228     src_key_padding_mask=None,
#     229     src_pos=img_pos_embeds.copy(),
#     230     prompt=prompt,
#     231     prompt_pos=prompt_pos_embed,
#     232     prompt_key_padding_mask=prompt_mask,
#     233     feat_sizes=vis_feat_sizes,
#     234     encoder_extra_kwargs=encoder_extra_kwargs,
#     235 )
#     236 encoder_out = {
#     237     # encoded image features
#     238     "encoder_hidden_states": memory["memory"],
#    (...)
#     248     "prompt_mask": prompt_mask,
#     249 }
#     250 return backbone_out, encoder_out, feat_tuple
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/encoder.py:562, in TransformerEncoderFusion.forward(self, src, prompt, src_key_padding_mask, src_pos, prompt_key_padding_mask, prompt_pos, feat_sizes, encoder_extra_kwargs)
#     550     pooled_text = self.text_pooling_proj(pooled_text)[
#     551         ..., None, None
#     552     ]  # prompt is seq first
#     553     src = [x.add_(pooled_text) for x in src]
#     555 (
#     556     out,
#     557     key_padding_masks_flatten,
#     558     lvl_pos_embed_flatten,
#     559     level_start_index,
#     560     spatial_shapes,
#     561     valid_ratios,
# --> 562 ) = super().forward(
#     563     src,
#     564     src_key_padding_masks=src_key_padding_mask,
#     565     pos=src_pos,
#     566     prompt=prompt.transpose(0, 1),
#     567     prompt_key_padding_mask=prompt_key_padding_mask,
#     568     encoder_extra_kwargs=encoder_extra_kwargs,
#     569 )
#     571 return {
#     572     "memory": out,
#     573     "padding_mask": key_padding_masks_flatten,
#    (...)
#     578     "valid_ratios": valid_ratios,
#     579 }
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/encoder.py:445, in TransformerEncoder.forward(self, src, src_key_padding_masks, pos, prompt, prompt_key_padding_mask, encoder_extra_kwargs)
#     443     if encoder_extra_kwargs is not None:
#     444         layer_kwargs.update(encoder_extra_kwargs)
# --> 445     output = activation_ckpt_wrapper(layer)(
#     446         **layer_kwargs,
#     447         act_ckpt_enable=self.training and self.use_act_checkpoint,
#     448     )
#     449 # return as seq first
#     450 return (
#     451     output.transpose(0, 1),
#     452     (
#    (...)
#     460     valid_ratios,
#     461 )
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/act_ckpt_utils.py:88, in activation_ckpt_wrapper.<locals>.act_ckpt_wrapper(act_ckpt_enable, use_reentrant, *args, **kwargs)
#      84     ret = checkpoint.checkpoint(
#      85         module, *args, use_reentrant=use_reentrant, **kwargs
#      86     )
#      87 else:
# ---> 88     ret = module(*args, **kwargs)
#      90 return ret
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/efficientsam3/lib/python3.10/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File /mnt/e/side_projects/efficientsam3/sam3/sam3/model/encoder.py:239, in TransformerEncoderLayer.forward(self, tgt, memory, dac, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, pos, query_pos)
#     219 """
#     220 Forward pass for the transformer encoder layer.
#     221
#    (...)
#     236     Processed tensor after self-attention, cross-attention, and feedforward network
#     237 """
#     238 fwd_fn = self.forward_pre if self.pre_norm else self.forward_post
# --> 239 return fwd_fn(
#     240     tgt,
#     241     memory,
#     242     dac=dac,
#     243     tgt_mask=tgt_mask,
#     244     memory_mask=memory_mask,
#     245     tgt_key_padding_mask=tgt_key_padding_mask,
#     246     memory_key_padding_mask=memory_key_padding_mask,
#     247     pos=pos,
#     248     query_pos=query_pos,
#     249     # attn_bias=attn_bias,
#     250     # **kwds,
#     251 )
#
# KeyboardInterrupt:

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 2
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [740, 450],  # positive click
        [760, 630],  # negative click
        [840, 640],  # negative click
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
# finally, close the inference session to free its GPU resources
# (you may start a new session on another video)
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)

# %% [markdown]
# ### Clean-up
#
# After all inference is done, we can shutdown the predictor to free up the multi-GPU process group.

# %%
# after all inference is done, we can shutdown the predictor
# to free up the multi-GPU process group
predictor.shutdown()
